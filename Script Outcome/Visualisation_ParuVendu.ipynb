# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
immo = pd.read_csv('ParuVendu.csv')

# %%
immo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12135 entries, 0 to 12134
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              12135 non-null  object
#  1   Nombre de Pièces  12135 non-null  int64
#  2   Surface (m²)      12135 non-null  int64
#  3   Prix (€)          12135 non-null  object
#  4   Departement       12135 non-null  int64
#  5   Code Postal       12135 non-null  int64
#  6   Emplacement       12135 non-null  object
#  7   Description       12135 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 758.6+ KB

# %%
immo.head()
# Out:
#           Type  Nombre de Pièces  Surface (m²)  Prix (€)  Departement  \
# 0       Maison                 7           190    770000           95
# 1  Appartement                 3            62    488000           92
# 2       Maison                 6           190    879000           95
# 3  Appartement                 2            60    225750           95
# 4  Appartement                 2            34    258750           92
#
#    Code Postal                Emplacement  \
# 0        95880  Enghien-les-Bains (95880)
# 1        92400         Courbevoie (92400)
# 2        95160        Montmorency (95160)
# 3        95100         Argenteuil (95100)
# 4        92320          Châtillon (92320)
#
#                                          Description  Prix (€)/m²
# 0  Maison/villa 7 pièces. a deux pas d'enghien le...  4052.631579
# 1  T3 3 pièces. courbevoie faubourg de l'arche  -...  7870.967742
# 2  Maison contemporaine 6 pièces. a 12 mn de gare...  4626.315789
# ...

# %%
sns.scatterplot(x='Prix (€)', y = 'Surface (m²)', data = immo, hue = 'Departement')
sns.rugplot(x='Prix (€)', y = 'Surface (m²)', data = immo, hue = 'Departement').set(title='Prix des Biens selon leur superficie')
# Out:
# [Text(0.5, 1.0, 'Prix des Biens selon leur superficie')]

# %%
sns.scatterplot(x='Departement', y = 'Prix (€)', data = immo,)
sns.rugplot(x='Departement', y = 'Prix (€)', data = immo).set(title='Prix des Bien selon leur Département')
# Out:
# [Text(0.5, 1.0, 'Prix des Bien selon leur Département')]

# %%
sns.countplot(y="Type", hue="Departement", data=immo).set(title='Nombre de biens vendus selon leur départements')
# Out:
# [Text(0.5, 1.0, 'Nombre de biens vendus selon leur départements')]

# %%
not_exp= immo.sort_values(by='Prix (€)')

# %%
immo = immo.drop(13)

# %%
p = sns.jointplot(x="Prix (€)", y = 'Surface (m²)', data=not_exp93.head(5), kind = 'hist')
p.fig.suptitle('Les 5 biens vendus les moins chers en Seine Saint Denis')
p.fig.tight_layout()
p.fig.subplots_adjust(top=0.95)

# %%
m = sns.jointplot(x="Prix (€)", y = 'Surface (m²)',data=not_exp94.head(5), kind='hist')
m.fig.suptitle('Les 5 biens vendus les moins chers dans le Val de Marne')
m.fig.tight_layout()
m.fig.subplots_adjust(top=0.95)

# %%
n = sns.jointplot(x="Prix (€)", y = 'Surface (m²)',data=not_exp95.head(5), kind='hist')
n.fig.suptitle('Les 5 biens vendus les moins chers dans le Val d\'Oise')
n.fig.tight_layout()
n.fig.subplots_adjust(top=0.95)

# %%
o = sns.jointplot(x="Prix (€)", y = 'Surface (m²)',data=not_exp92.head(5), kind='hex')
o.fig.suptitle('Les 5 biens vendus les moins chers dans les Hauts-de-Seine')
o.fig.tight_layout()
o.fig.subplots_adjust(top=0.95)

# %%
q = sns.jointplot(x="Prix (€)", y = 'Surface (m²)',data=not_exp91.head(5), kind='hex')
q.fig.suptitle('Les 5 biens vendus les moins chers dans l\'Essone')
q.fig.tight_layout()
q.fig.subplots_adjust(top=0.95)

# %%
r=sns.jointplot(x="Prix (€)", y = 'Surface (m²)',data=not_exp78.head(5), kind='hex')
r.fig.suptitle('Les 5 biens vendus les moins chers dans les Yvelines')
r.fig.tight_layout()
r.fig.subplots_adjust(top=0.95)

# %%
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp77.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)',hue="Departement", data=not_exp75.head(5) )
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp78.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp91.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp92.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp95.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp93.head(5))
# Out:
# <AxesSubplot:xlabel='Prix (€)', ylabel='Surface (m²)'>

# %%
s=sns.jointplot(x="Prix (€)", y = 'Surface (m²)', data=not_exp75.head(5), kind='hist')
s.fig.suptitle('Les 5 biens vendus les moins chers dans Paris')
s.fig.tight_layout()
s.fig.subplots_adjust(top=0.95)

# %%
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp77.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)',hue="Departement", data=not_exp75.head(5) )
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp78.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp91.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp92.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp95.head(5))
sns.histplot(x="Prix (€)", y = 'Surface (m²)', hue="Departement", data=not_exp93.head(5))

# %%
not_exp75 = not_exp[not_exp['Departement'] == '75']

# %%
not_exp93 = not_exp[not_exp['Departement'] == '93']

# %%
not_exp77 = not_exp[not_exp['Departement'] == '77']

# %%
not_exp78 = not_exp[not_exp['Departement'] == '78']

# %%
not_exp91 = not_exp[not_exp['Departement'] == '91']

# %%
not_exp92 = not_exp[not_exp['Departement'] == '92']

# %%
not_exp= immo.sort_values(by='Prix (€)')
not_exp95 = not_exp[not_exp['Departement'] == '95']
not_exp94 = not_exp[not_exp['Departement'] == '94']
not_exp92 = not_exp[not_exp['Departement'] == '92']
not_exp91 = not_exp[not_exp['Departement'] == '91']
not_exp75 = not_exp[not_exp['Departement'] == '75']
not_exp78 = not_exp[not_exp['Departement'] == '78']
not_exp93 = not_exp[not_exp['Departement'] == '93']

# %%
not_exp94 = not_exp[not_exp['Departement'] == '94']

# %%
immo.to_csv('ParuVendu.csv', index = False, header = True, encoding="UTF-8" )
